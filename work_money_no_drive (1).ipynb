# %% [markdown]
# # *Lab DL / Project 4*

# %% [markdown]
# ## import data

# %% [markdown]
# ### Imports

# %%
import os
import random
import zipfile

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Seeds

# %%
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### conecting

# %%
# Google Drive is not needed in this version.
print('Using Colab local storage — Google Drive is not connected.')
# Out:
# Using Colab local storage — Google Drive is not connected.

# %% [markdown]
# ### Dataset Path

# %%
import os

print(os.path.exists("/content/Currency.zip"))
# Out:
# True

# %%
print(os.listdir("/content"))
# Out:
# ['.config', 'currency_data', 'currency_model_data', 'Currency.zip', 'sample_data']

# %%
from google.colab import files
import os
import shutil

# Upload Currency.zip directly from your computer
if not os.path.exists('/content/Currency.zip'):
    uploaded = files.upload()

print('Currency.zip is ready in Colab!')
# Out:
# Currency.zip is ready in Colab!

# %%
# Google Drive is not needed in this version.
print('Using Colab local storage — Google Drive is not connected.')
# Out:
# Using Colab local storage — Google Drive is not connected.

# %%
print(os.listdir('/content'))
# Out:
# ['.config', 'currency_data', 'currency_model_data', 'Currency.zip', 'sample_data']

# %%
print(os.path.exists('/content/Currency.zip'))
# Out:
# True

# %%
zip_path = "/content/Currency.zip"

# %%
extract_path = "/content/currency_data"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
print(os.listdir(extract_path))
# Out:
# ['Currency']

# %%
currency_path = "/content/currency_data/Currency"

print(os.listdir(currency_path))
# Out:
# ['20 BD', '1BD', '0.05', '10 BD', '0.50', '0.100', '5 BD', '0.25', '0.5 BD']

# %%
for folder in os.listdir(currency_path):
    folder_path = os.path.join(currency_path, folder)

    print(folder, "->", os.listdir(folder_path)[:10])
# Out:
# 20 BD -> ['bhd20_006.png', 'bhd20_015.png', 'bhd20_041.png', 'bhd20_030.png', 'bhd20_050.png', 'bhd20_039.png', 'bhd20_027.png', 'WhatsApp Image 2026-08-06 at 2.53.58 PM (1) - Copy.jpeg', 'WhatsApp Image 2026-08-06 at 2.54.01 PM (2).jpeg', 'bhd20_028.png']
# 1BD -> ['bhd1_042.png', 'WhatsApp Image 2026-08-06 at 4.28.44 PM (4).jpeg', 'WhatsApp Image 2026-08-06 at 2.53.54 PM (4).jpeg', 'bhd1_008.png', 'bhd1_044.png', 'bhd1_032.png', 'bhd1_041.png', 'WhatsApp Image 2026-08-06 at 4.28.44 PM (1).jpeg', 'bhd1_027.png', 'bhd1_045.png']
# 0.05 -> ['bahrain_5fils_29.jpg', 'bahrain_5fils_03.jpg', 'bahrain_5fils_19.jpg', 'bahrain_5fils_10.jpg', 'bahrain_5fils_15.jpg', 'bahrain_5fils_01.jpg', 'bahrain_5fils_44.jpg', 'bahrain_5fils_11.jpg', 'bahrain_5fils_12.jpg', 'bahrain_5fils_18.jpg']
# 10 BD -> ['bhd10_008.png', 'bhd10_045.png', 'bhd10_013.png', 'WhatsApp Image 2026-08-06 at 2.53.58 PM (3).jpeg', 'bhd10_010.png', 'bhd10_017.png', 'bhd10_016.png', 'WhatsApp Image 2026-08-06 at 2.53.59 PM (4) - Copy.jpeg', 'bhd10_027.png', 'bhd10_046.png']
# 0.50 -> ['bhd50f_013.png', 'bhd50f_003.png', 'bhd50f_041.png', 'bhd50f_016.png', 'bhd50f_019.png', 'bhd50f_021.png', 'bhd50f_025.png', 'bhd50f_024.png', 'bhd50f_036.png', 'bhd50f_040.png']
# 0.100 -> ['bhd100f_005.png', 'bhd100f_047.png', 'bhd100f_010.png', 'bhd100f_027.png', 'bhd100f_044.png', 'bhd100f_032.png', 'bhd100f_036.png', 'bhd100f_034.png', 'bhd100f_048.png', 'bhd100f_037.png']
# 5 BD -> ['bhd5_022.png', 'bhd5_028.png', 'WhatsApp Image 2026-08-06 at 2.53.56 PM (4).jpeg', 'WhatsApp Image 2026-08-06 at 2.53.57 PM (4).jpeg', 'bhd5_031.png', 'bhd5_035.png', 'bhd5_003.png', 'bhd5_019.png', 'bhd5_029.png', 'bhd5_010.png']
# 0.25 -> ['bhd25f_032.png', 'bhd25f_011.png', 'bhd25f_012.png', 'bhd25f_003.png', '13.png', 'bhd25f_019.png', '12.png', 'bhd25f_025.png', 'bhd25f_002.png', 'bhd25f_031.png']
# 0.5 BD -> ['bhd500f_032.png', 'bhd500f_023.png', 'bhd500f_050.png', 'bhd500f_043.png', 'bhd500f_044.png', 'bhd500f_040.png', 'bhd500f_036.png', 'bhd500f_038.png', 'bhd500f_037.png', 'WhatsApp Image 2026-08-06 at 2.53.52 PM (2) - Copy.jpeg']

# %%
train_path = "/content/currency_data/Currency"
test_path = "/content/currency_data/Currency"

# %%
for folder in os.listdir(currency_path):
    train_folder = os.path.join(currency_path, folder)
    test_folder = os.path.join(currency_path, folder)

    train_images = len(os.listdir(train_folder))
    test_images = len(os.listdir(test_folder))

    print(folder, "-> Train:", train_images, "| Test:", test_images)
# Out:
# 20 BD -> Train: 50 | Test: 50
# 1BD -> Train: 50 | Test: 50
# 0.05 -> Train: 50 | Test: 50
# 10 BD -> Train: 50 | Test: 50
# 0.50 -> Train: 50 | Test: 50
# 0.100 -> Train: 50 | Test: 50
# 5 BD -> Train: 50 | Test: 50
# 0.25 -> Train: 50 | Test: 50
# 0.5 BD -> Train: 50 | Test: 50

# %%
model_data_path = "/content/currency_model_data"

train_model_path = os.path.join(model_data_path, "Train")
test_model_path = os.path.join(model_data_path, "Test")

os.makedirs(train_model_path, exist_ok=True)
os.makedirs(test_model_path, exist_ok=True)

# %%
for folder in os.listdir(currency_path):

    original_train = os.path.join(currency_path, folder)
    original_test = os.path.join(currency_path, folder)

    new_train = os.path.join(train_model_path, folder)
    new_test = os.path.join(test_model_path, folder)

    os.makedirs(new_train, exist_ok=True)
    os.makedirs(new_test, exist_ok=True)

    for file in os.listdir(original_train):
        shutil.copy(
            os.path.join(original_train, file),
            os.path.join(new_train, file)
        )

    for file in os.listdir(original_test):
        shutil.copy(
            os.path.join(original_test, file),
            os.path.join(new_test, file)
        )

print("Dataset prepared successfully!")
# Out:
# Dataset prepared successfully!

# %%
print(os.listdir(train_model_path))
print(os.listdir(test_model_path))
# Out:
# ['20 BD', '1BD', '0.05', '10 BD', '0.50', '0.100', '5 BD', '0.25', '0.5 BD']
# ['20 BD', '1BD', '0.05', '10 BD', '0.50', '0.100', '5 BD', '0.25', '0.5 BD']

# %%
train_datagen = ImageDataGenerator(
    rescale=1/255
)

test_datagen = ImageDataGenerator(
    rescale=1/255
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_model_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 450 images belonging to 9 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    test_model_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 450 images belonging to 9 classes.

# %%
# Preprocessing

IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=(0.8, 1.2)
)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    train_model_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    test_model_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

class_names = list(train_generator.class_indices.keys())
print("Classes:", class_names)
print("Number of classes:", len(class_names))
# Out:
# Found 450 images belonging to 9 classes.
# Found 450 images belonging to 9 classes.
# Classes: ['0.05', '0.100', '0.25', '0.5 BD', '0.50', '10 BD', '1BD', '20 BD', '5 BD']
# Number of classes: 9

# %%
test_loss, test_accuracy = model.evaluate(test_generator)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_837/3982440107.py in <cell line: 0>()
# ----> 1 test_loss, test_accuracy = model.evaluate(test_generator)
#       2
#       3 print("Test Loss:", test_loss)
#       4 print("Test Accuracy:", test_accuracy)
#
# NameError: name 'model' is not defined

# %%
train_loss, train_accuracy = model.evaluate(train_generator)

print("Train Loss:", train_loss)
print("Train Accuracy:", train_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_837/3623285152.py in <cell line: 0>()
# ----> 1 train_loss, train_accuracy = model.evaluate(train_generator)
#       2
#       3 print("Train Loss:", train_loss)
#       4 print("Train Accuracy:", train_accuracy)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Model Training

# %%
# Step 1
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Step 2
model = Sequential()

model.add(Flatten(input_shape=(224, 224, 3)))  # image 3D -> 1D

model.add(Dense(500, activation='relu'))  # hidden layer
model.add(Dense(200, activation='relu'))  # hidden layer
model.add(Dense(100, activation='relu'))  # hidden layer

model.add(Dense(len(class_names), activation='softmax'))  # output layer


model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 150528)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 500)            │    75,264,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 200)            │       100,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 9)              │           909 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,385,709 (287.57 MB)
#  Trainable params: 75,385,709 (287.57 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Step 3: Compile
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Step 4: Fitting (Learning)

history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=50
)
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.0933 - loss: 79.2723 - val_accuracy: 0.1089 - val_loss: 53.2662
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.1222 - loss: 30.4123 - val_accuracy: 0.1111 - val_loss: 35.0264
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.1311 - loss: 16.0699 - val_accuracy: 0.1089 - val_loss: 10.5779
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.1378 - loss: 10.0664 - val_accuracy: 0.1444 - val_loss: 9.5074
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.1111 - loss: 9.2300 - val_accuracy: 0.1600 - val_loss: 8.7002
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.1467 - loss: 7.1716 - val_accuracy: 0.1289 - val_loss: 7.2304
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.1733 - loss: 5.8353 - val_accuracy: 0.1467 - val_loss: 3.4211
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.2400 - loss: 3.7741 - val_accuracy: 0.2311 - val_loss: 2.8561
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.1889 - loss: 3.6619 - val_accuracy: 0.2089 - val_loss: 4.3926
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.1956 - loss: 3.4277 - val_accuracy: 0.2711 - val_loss: 2.7895
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.2200 - loss: 3.5216 - val_accuracy: 0.2733 - val_loss: 3.4815
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.2133 - loss: 4.1685 - val_accuracy: 0.1533 - val_loss: 4.5131
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.1867 - loss: 3.7552 - val_accuracy: 0.3956 - val_loss: 2.8721
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.2289 - loss: 3.7626 - val_accuracy: 0.1400 - val_loss: 5.1676
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.1956 - loss: 4.7323 - val_accuracy: 0.1711 - val_loss: 3.5053
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.1933 - loss: 3.2528 - val_accuracy: 0.2778 - val_loss: 2.6809
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.2200 - loss: 3.3549 - val_accuracy: 0.2578 - val_loss: 4.2441
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.2333 - loss: 4.1320 - val_accuracy: 0.2222 - val_loss: 3.2483
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.2956 - loss: 2.2795 - val_accuracy: 0.2422 - val_loss: 2.4367
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.2267 - loss: 2.5643 - val_accuracy: 0.3756 - val_loss: 1.8770
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.2911 - loss: 2.3618 - val_accuracy: 0.3222 - val_loss: 2.2988
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3356 - loss: 1.9595 - val_accuracy: 0.4200 - val_loss: 1.8036
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3622 - loss: 1.7921 - val_accuracy: 0.2756 - val_loss: 2.9296
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.2756 - loss: 2.6257 - val_accuracy: 0.2911 - val_loss: 2.4437
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3467 - loss: 2.2047 - val_accuracy: 0.4889 - val_loss: 1.6515
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3978 - loss: 1.8257 - val_accuracy: 0.4711 - val_loss: 1.5707
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.3933 - loss: 1.7598 - val_accuracy: 0.2444 - val_loss: 2.3077
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.1844 - loss: 3.1325 - val_accuracy: 0.2467 - val_loss: 2.4018
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3044 - loss: 2.0512 - val_accuracy: 0.2556 - val_loss: 3.4887
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.2800 - loss: 2.5803 - val_accuracy: 0.2667 - val_loss: 2.7924
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3222 - loss: 2.2792 - val_accuracy: 0.3756 - val_loss: 1.9017
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3111 - loss: 2.1309 - val_accuracy: 0.3311 - val_loss: 2.0708
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3778 - loss: 1.8490 - val_accuracy: 0.4578 - val_loss: 1.7242
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3689 - loss: 2.3498 - val_accuracy: 0.4289 - val_loss: 1.5459
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.3956 - loss: 1.7545 - val_accuracy: 0.3556 - val_loss: 1.8659
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.3422 - loss: 1.8581 - val_accuracy: 0.4089 - val_loss: 1.5700
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3444 - loss: 2.1245 - val_accuracy: 0.3756 - val_loss: 2.7186
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.3200 - loss: 2.5658 - val_accuracy: 0.5089 - val_loss: 1.3985
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3933 - loss: 1.7714 - val_accuracy: 0.3911 - val_loss: 1.8488
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4267 - loss: 1.5814 - val_accuracy: 0.3889 - val_loss: 1.6189
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.3533 - loss: 2.1784 - val_accuracy: 0.3889 - val_loss: 2.5242
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4089 - loss: 1.7968 - val_accuracy: 0.4356 - val_loss: 1.6708
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.4022 - loss: 1.7393 - val_accuracy: 0.4778 - val_loss: 1.4709
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.3711 - loss: 1.9383 - val_accuracy: 0.4578 - val_loss: 1.3644
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.3533 - loss: 1.7740 - val_accuracy: 0.3578 - val_loss: 1.9037
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.3867 - loss: 1.6708 - val_accuracy: 0.5733 - val_loss: 1.2188
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.5022 - loss: 1.4360 - val_accuracy: 0.4578 - val_loss: 1.4972
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4756 - loss: 1.4546 - val_accuracy: 0.5333 - val_loss: 1.2749
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.4600 - loss: 1.4292 - val_accuracy: 0.4533 - val_loss: 1.4981
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.4889 - loss: 1.4885 - val_accuracy: 0.4822 - val_loss: 1.3386

# %%
# history
history_df = pd.DataFrame(history.history)
history_df
# Out:
#     accuracy       loss  val_accuracy   val_loss
# 0   0.093333  79.272263      0.108889  53.266163
# 1   0.122222  30.412300      0.111111  35.026440
# 2   0.131111  16.069927      0.108889  10.577929
# 3   0.137778  10.066420      0.144444   9.507392
# 4   0.111111   9.229995      0.160000   8.700192
# 5   0.146667   7.171556      0.128889   7.230373
# 6   0.173333   5.835342      0.146667   3.421054
# 7   0.240000   3.774077      0.231111   2.856113
# 8   0.188889   3.661897      0.208889   4.392597
# 9   0.195556   3.427721      0.271111   2.789512
# 10  0.220000   3.521615      0.273333   3.481544
# 11  0.213333   4.168459      0.153333   4.513116
# 12  0.186667   3.755237      0.395556   2.872079
# 13  0.228889   3.762576      0.140000   5.167584
# 14  0.195556   4.732296      0.171111   3.505264
# 15  0.193333   3.252753      0.277778   2.680928
# 16  0.220000   3.354909      0.257778   4.244134
# 17  0.233333   4.132000      0.222222   3.248311
# 18  0.295556   2.279500      0.242222   2.436730
# 19  0.226667   2.564289      0.375556   1.876994
# 20  0.291111   2.361801      0.322222   2.298784
# 21  0.335556   1.959549      0.420000   1.803602
# 22  0.362222   1.792117      0.275556   2.929599
# 23  0.275556   2.625666      0.291111   2.443723
# 24  0.346667   2.204702      0.488889   1.651514
# 25  0.397778   1.825748      0.471111   1.570674
# 26  0.393333   1.759753      0.244444   2.307670
# 27  0.184444   3.132506      0.246667   2.401785
# 28  0.304444   2.051164      0.255556   3.488743
# 29  0.280000   2.580263      0.266667   2.792399
# 30  0.322222   2.279195      0.375556   1.901728
# 31  0.311111   2.130935      0.331111   2.070833
# 32  0.377778   1.848993      0.457778   1.724185
# 33  0.368889   2.349817      0.428889   1.545886
# 34  0.395556   1.754456      0.355556   1.865949
# 35  0.342222   1.858115      0.408889   1.570011
# 36  0.344444   2.124523      0.375556   2.718597
# 37  0.320000   2.565832      0.508889   1.398517
# 38  0.393333   1.771399      0.391111   1.848754
# 39  0.426667   1.581410      0.388889   1.618934
# 40  0.353333   2.178436      0.388889   2.524214
# 41  0.408889   1.796838      0.435556   1.670845
# 42  0.402222   1.739287      0.477778   1.470905
# 43  0.371111   1.938259      0.457778   1.364355
# 44  0.353333   1.774005      0.357778   1.903745
# 45  0.386667   1.670810      0.573333   1.218768
# 46  0.502222   1.435983      0.457778   1.497221
# 47  0.475556   1.454555      0.533333   1.274884
# 48  0.460000   1.429227      0.453333   1.498050
# 49  0.488889   1.488491      0.482222   1.338600

# %%
history_df[['accuracy', 'val_accuracy']].plot()
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.show()

# %%
history_df[["loss", "val_loss"]].plot()
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# ## Evaluation

# %%
# Step 5: Prediction

test_generator.reset()
y_pred = model.predict(test_generator)
y_pred_label = np.argmax(y_pred, axis=1)
y_test = test_generator.classes

print("Accuracy:", accuracy_score(y_test, y_pred_label))
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 462ms/step
# Accuracy: 0.4822222222222222

# %%
model.evaluate(test_generator)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 448ms/step - accuracy: 0.4822 - loss: 1.3386
# [1.3386000394821167, 0.48222222924232483]

# %%
print(classification_report(
    y_test,
    y_pred_label,
    target_names=class_names
))
# Out:
#               precision    recall  f1-score   support
#
#         0.05       0.83      0.50      0.62        50
#        0.100       0.82      0.28      0.42        50
#         0.25       0.00      0.00      0.00        50
#       0.5 BD       0.27      0.88      0.42        50
#         0.50       0.32      0.52      0.40        50
#        10 BD       0.92      0.46      0.61        50
#          1BD       0.39      0.36      0.38        50
#        20 BD       0.67      0.36      0.47        50
#         5 BD       0.78      0.98      0.87        50
#
#     accuracy                           0.48       450
#    macro avg       0.56      0.48      0.46       450
# weighted avg       0.56      0.48      0.46       450
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
conf_matrix = confusion_matrix(y_test, y_pred_label)
conf_matrix
# Out:
# array([[25,  0,  0,  7,  9,  0,  2,  3,  4],
#        [ 0, 14,  0, 23, 13,  0,  0,  0,  0],
#        [ 5,  0,  0, 14, 22,  0,  8,  1,  0],
#        [ 0,  0,  0, 44,  1,  0,  4,  1,  0],
#        [ 0,  3,  0, 12, 26,  0,  7,  2,  0],
#        [ 0,  0,  0, 16,  6, 23,  2,  1,  2],
#        [ 0,  0,  0, 27,  4,  0, 18,  1,  0],
#        [ 0,  0,  0, 17,  0,  2,  5, 18,  8],
#        [ 0,  0,  0,  1,  0,  0,  0,  0, 49]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred_label,
    display_labels=class_names,
    xticks_rotation=45
)
plt.show()

# %% [markdown]
# ## Error Analysis

# %%
idx = np.where(y_test != y_pred_label)[0]
print("Number of wrong predictions:", len(idx))
idx[:25]
# Out:
# Number of wrong predictions: 233
# array([ 0,  1,  3,  7,  9, 10, 12, 13, 14, 15, 18, 20, 22, 23, 24, 27, 28,
#        33, 36, 37, 39, 41, 44, 47, 48])

# %%
# Show some images the model got wrong

test_generator.reset()
images, labels = next(test_generator)

plt.figure(figsize=(10, 10))

shown = 0
for i in range(len(images)):
    if y_test[i] != y_pred_label[i]:
        plt.subplot(5, 5, shown + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i])
        plt.xlabel(
            f"True: {class_names[y_test[i]]}\n"
            f"Pred: {class_names[y_pred_label[i]]}"
        )
        shown += 1
        if shown == 25:
            break

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Key Questions

# %%
print("Most confused classes can be seen in the confusion matrix above.")
print("Similar-looking notes can be checked from the misclassified images.")
print("Background effects can be checked using new images with unseen backgrounds.")
# Out:
# Most confused classes can be seen in the confusion matrix above.
# Similar-looking notes can be checked from the misclassified images.
# Background effects can be checked using new images with unseen backgrounds.

# %% [markdown]
# ## Streamlit Deployment + API

# %%
model.save("currency_model.keras")

# %%
from google.colab import files

files.download('/content/currency_model.keras')

# %%
# Save the trained model

model.save("/content/currency_model.keras")
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
# Create Streamlit app

app_code = '''
import streamlit as st
import numpy as np
from PIL import Image
import tensorflow as tf

model = tf.keras.models.load_model("currency_model.keras")

class_names = %r

st.title("Bahraini Currency Recognition")

uploaded_file = st.file_uploader("Upload a currency image", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    image = Image.open(uploaded_file).convert("RGB")
    st.image(image, caption="Uploaded Image", use_container_width=True)

    image = image.resize((224, 224))
    image_array = np.array(image) / 255.0
    image_array = np.expand_dims(image_array, axis=0)

    prediction = model.predict(image_array)
    predicted_class = np.argmax(prediction[0])
    confidence = prediction[0][predicted_class]

    st.write("Prediction:", class_names[predicted_class])
    st.write("Confidence:", float(confidence))
''' % class_names

with open("/content/app.py", "w") as f:
    f.write(app_code)

print("app.py created successfully!")
# Out:
# app.py created successfully!

# %% [markdown]
# ## Final Reflection
#
# 1. Why did classification work well initially?
# 2. What problems did object detection solve?
# 3. Which approach is more suitable for real-world deployment?
# 4. How would you improve the system further?

# %% [markdown]
# ## Notes
#
# The dataset used in this notebook contains 9 currency classes. The model output layer therefore uses the number of classes detected from the dataset.
